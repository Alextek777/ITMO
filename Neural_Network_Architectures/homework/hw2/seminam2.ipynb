# %%
import torch
import torch.nn as nn 



class LeNet(nn.Module):
    def __init__(self, num_classes=10):
        super(LeNet, self).__init__()

        self.conv1 = nn.Conv2d(1, 6, kernel_size=5, stride=1, padding=2)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5, stride=1, padding=2)
        self.conv3 = nn.Conv2d(16, 120, kernel_size=5, stride=1, padding=2)

        self.fc1 = nn.Linear(120, 84)
        self.fc2 = nn.Linear(84, num_classes)

        self.avgPool = nn.AvgPool2d(kernel_size=2, stride=2)
        self.activation = nn.Tanh()


    def forward(self, x):
        x = self.conv1(x)
        x = self.activation(x)
        x = self.avgPool(x)

        x = self.conv2(x)
        x = self.activation(x)
        x = self.avgPool(x)

        x = self.conv3(x)
        x = self.activation(x)

        x = torch.flatten(x, 1)

        x = self.fc1(x) 
        x = self.activation(x)

        x = self.fc2(x)
        x = self.activation(x)

        return x

# %%
model = LeNet(num_classes=10)

# %%
pred, activations = model(torch.randn(1, 1, 32, 32))
print(pred.shape)

_ = model._verify_variances()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 pred, activations = model(torch.randn(1, 1, 32, 32))
#       2 print(pred.shape)
#       4 _ = model._verify_variances()
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# Cell In [4], line 35, in LeNet.forward(self, x)
#      31 x = self.relu(x)
#      33 x = torch.flatten(x, 1)
# ---> 35 x = self.fc1(x)
#      36 x = self.relu(x)
#      38 x = self.fc2(x)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.11/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (1x7680 and 120x84)
